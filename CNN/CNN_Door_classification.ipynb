# %% [markdown]
# ##Import packages and images

# %%
import warnings
warnings.filterwarnings("ignore") 
import os
import shutil
import glob

# %%
from google.colab import drive # Set up the path (read files in google drive)
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
TRAIN_DIR = "./DATASET"
ORG_DIR = "/content/drive/MyDrive/Training_data - Cut" # import data (path)
CLASS = ['Door_number','No_number']

# %%
for C in CLASS:
  DEST = os.path.join(TRAIN_DIR,C)

  if not os.path.exists( DEST):
    os.makedirs(DEST)

  for img_path in glob.glob(os.path.join(ORG_DIR,C)+"*"):
    SRC = img_path

    shutil.copy(SRC,DEST)

# %% [markdown]
# ##Model building

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from keras.layers import Dense, Flatten
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import keras

# %%
base_model = InceptionV3(input_shape = (256,256,3), include_top= False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
X= Flatten()(base_model.output)
X = Dense(units = 2, activation = 'sigmoid')(X)

#Final model
model = Model(base_model.input, X)

#Compile the model
model.compile(optimizer = 'adam',loss = keras.losses.binary_crossentropy, metrics=['accuracy'])

# %% [markdown]
# ##Data pre-processing

# %%
train_datagen = ImageDataGenerator(featurewise_center=True, 
                                   rotation_range= 0.4, width_shift_range= 0.3, 
                                   horizontal_flip=True, preprocessing_function= preprocess_input, 
                                   zoom_range=0.4 , shear_range= 0.4 )
train_data = train_datagen.flow_from_directory(directory = "/content/DATASET", target_size = (256,256), batch_size = 36 )
# Out:
# Found 156 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'Door_number': 0, 'No_number': 1}

# %% [markdown]
# ##Data Visualization

# %%
t_img, label =train_data.next()

# %%
t_img.shape
# Out:
# (36, 256, 256, 3)

# %%
def plotimages(img_arr, label):
  """
  input: image array
  output: plot images
  """
  for idx,img in enumerate(img_arr):
    if idx<=10 :
      plt.figure(figsize=(5,5))
      plt.imshow(img)
      plt.title(img.shape)
      plt.axis=False
      plt.show()

# %%
plotimages(t_img, label)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ##Model evaluation

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

mc = ModelCheckpoint(filepath= "./CNN_model.h5",
                     monitor="accuracy",
                     verbose=1,
                     save_best_only=True)

es = EarlyStopping(monitor="accuracy",
                   min_delta = 0.01,
                   patience=5,
                   verbose=1)

cb= [mc,es]

# %%
his = model.fit_generator(train_data, steps_per_epoch=10, epochs=30, callbacks=cb)
# Out:
# Epoch 1/30
#  5/10 [==============>...............] - ETA: 28s - loss: 3.5715 - accuracy: 0.6538WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 300 batches). You may need to use the repeat() function when building your dataset.
#
# Epoch 1: accuracy improved from -inf to 0.65385, saving model to ./CNN_model.h5
# 10/10 [==============================] - 39s 3s/step - loss: 3.5715 - accuracy: 0.6538

# %%
scores = model.evaluate(t_img, label)
scores
# Out:
# 2/2 [==============================] - 6s 582ms/step - loss: 1.6178 - accuracy: 0.8611
# [1.6177613735198975, 0.8611111044883728]

# %% [markdown]
# ##Validate model (Load pre-trained model without training again)

# %%
from keras.models import load_model
model = load_model("/content/CNN_model.h5")

# %%
from matplotlib import image
# path for the image to see prediction result
path="/content/drive/MyDrive/Testing_data - Cut/Door_number (5).jpg" #copy path of image from test1 folder ( put any new image to here for classification)
img = load_img(path,target_size=(256,256))
i = img_to_array(img)
i= preprocess_input(i)
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

if pred==0:
  print("The image has Door_number")
else:
  print("The image has No_number")

#Plot the image
plt.imshow(input_arr[0])
plt.title("input image")
plt.axis=False
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The image has Door_number
